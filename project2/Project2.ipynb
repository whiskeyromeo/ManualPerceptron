# %% [markdown]
# Will Russell
#
# Ayush Rohatgi

# %% [markdown]
# ## Analysis
# - Scenario A:
#     - The splits obtained for Scenario A were overall slightly less accurate than that of the models generated in Scenario B. This may be expected to some degree in that with Scenario A we only have a single feature from which we may try to delineate the decision function. When the models were generated multiple times, overall the accuracy of the models which were trained using the soft activation method were more accurate than those trained using hard activation.
#     - Using hard activation, it accuracy will increase sporadically between the different train/test models generated using the same alpha measure. Generally the 50/50 split performs better, however this is not always the case. These results are consistent with the expected behavior of a perceptron due to the overlapping nature of the data. The ultimate weights achieved using the hard activatio function on this type of data are not necessarily the lowest envountered, they are simply where the modification stopped after the maximum number of iterations had been cycled.
#     - Using soft activation, the best accuracy was suprisingly found using the 25/75 split ratio, which was closely followed by the 50/50 split. The 25/75 split fared rather poorly compared to the other soft activation tests but still outperformed the best run of the 50/50 hard activation split.
#
# - Scenario B:
#     - The

# %% [markdown]
# ## Graphing
# - Below is the basic graphing module for the project. The code for the displayPerceptron method can be found in the **project_code/display.py** file. The source of the test data is the **data.txt** file located in the current directory.
# - The displayPerceptron method takes 6 optional parameters:
#     * ratio : Represents the Train/Test Ratio as a decimal( Default is .75 or 75% train/25% test)
#     * activation : Represents the type of activation function to be used(Currently 2 options, "hard" or "soft")
#     * alpha : Represents the learning rate of the Perceptron(Default is 0.1)
#     * iterations : The number of iterations to train the model for
#     * dimensions : The number of weights ( excluding bias)
#     * weights : An option to start with a preset weight, if not declared a set of random values between 0 and 1 will be used.
# - The method then displays a graph based on the parameters used and shows the final error rate established during training.
#     - *Note: This is not the test error rate*
# - Animations corresponding to the training can be found in **Project2_Perceptron_Animated.ipynb**

# %%
from project_code.display import *
# %matplotlib inline

# %% [markdown]
# ## Scenario A:

# %%
displayPerceptron(ratio=0.75, activation="hard", alpha=0.1, iterations=1000, dimensions=1, weights=None)
displayPerceptron(ratio=0.50, activation="hard", alpha=0.1, iterations=1000, dimensions=1, weights=[0.,0.])
displayPerceptron(ratio=0.25, activation="hard", alpha=0.1, iterations=1000, dimensions=1, weights=[0.,0.])
# Out:
# male correct, true positive : 0.724
# male errors, false positive : 0.276
# female errors, false negative : 0.088
# female correct, true negative : 0.912
# Accuracy : 0.818
# Error: 0.182
# male correct, true positive : 0.84
# male errors, false positive : 0.16
# female errors, false negative : 0.156
# female correct, true negative : 0.844
# Accuracy : 0.842
# Error: 0.158
# male correct, true positive : 0.7453333333333333
# male errors, false positive : 0.25466666666666665
# female errors, false negative : 0.09533333333333334
# female correct, true negative : 0.9046666666666666
# Accuracy : 0.825
# Error: 0.175

# %%
displayPerceptron(ratio=0.75, activation="soft", alpha=0.1, iterations=1000, dimensions=1, weights=[0.,0.])
displayPerceptron(ratio=0.50, activation="soft", alpha=0.1, iterations=1000, dimensions=1, weights=[0.,0.])
displayPerceptron(ratio=0.25, activation="soft", alpha=0.1, iterations=1000, dimensions=1, weights=[0.,0.])
# Out:
# male correct, true positive : 0.846
# male errors, false positive : 0.154
# female errors, false negative : 0.17
# female correct, true negative : 0.83
# Accuracy : 0.838
# Error: 0.162
# male correct, true positive : 0.767
# male errors, false positive : 0.233
# female errors, false negative : 0.105
# female correct, true negative : 0.895
# Accuracy : 0.831
# Error: 0.169
# male correct, true positive : 0.826
# male errors, false positive : 0.174
# female errors, false negative : 0.142
# female correct, true negative : 0.858
# Accuracy : 0.842
# Error: 0.158

# %% [markdown]
# ## Scenario B

# %%
displayPerceptron(ratio=0.75, activation="hard", alpha=0.1, iterations=1000, dimensions=2, weights=[0.,0.,0.])
displayPerceptron(ratio=0.50, activation="hard", alpha=0.1, iterations=1000, dimensions=2, weights=[0.,0.,0.])
displayPerceptron(ratio=0.25, activation="hard", alpha=0.1, iterations=1000, dimensions=2, weights=[0.,0.,0.])
# Out:
# male correct, true positive : 0.984
# male errors, false positive : 0.016
# female errors, false negative : 0.286
# female correct, true negative : 0.714
# Accuracy : 0.849
# Error: 0.151
# male correct, true positive : 0.857
# male errors, false positive : 0.143
# female errors, false negative : 0.034
# female correct, true negative : 0.966
# Accuracy : 0.9115
# Error: 0.0885
# male correct, true positive : 0.8653333333333333
# male errors, false positive : 0.13466666666666666
# female errors, false negative : 0.035333333333333335
# female correct, true negative : 0.9646666666666667
# Accuracy : 0.915
# Error: 0.085

# %%
displayPerceptron(ratio=0.75, activation="soft", alpha=0.1, iterations=1000, dimensions=2, weights=[0.,0.,0.])
displayPerceptron(ratio=0.50, activation="soft", alpha=0.1, iterations=1000, dimensions=2, weights=[0.,0.,0.])
displayPerceptron(ratio=0.25, activation="soft", alpha=0.1, iterations=1000, dimensions=2, weights=[0.,0.,0.])
# Out:
# male correct, true positive : 0.924
# male errors, false positive : 0.076
# female errors, false negative : 0.106
# female correct, true negative : 0.894
# Accuracy : 0.909
# Error: 0.091
# male correct, true positive : 0.936
# male errors, false positive : 0.064
# female errors, false negative : 0.102
# female correct, true negative : 0.898
# Accuracy : 0.917
# Error: 0.083
# male correct, true positive : 0.896
# male errors, false positive : 0.104
# female errors, false negative : 0.050666666666666665
# female correct, true negative : 0.9493333333333334
# Accuracy : 0.9227
# Error: 0.0773
