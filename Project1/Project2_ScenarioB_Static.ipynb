# %%
from project_code.fileWorker import retrieve_students
import random
import numpy as np
import matplotlib.pyplot as plt
from project_code.data import normalize_student_data, separate_normalized_students, separate_and_normalize_students
from project_code.perceptron import Perceptron
from project_code.graphlib import plot_normalized_data, plot_animated_data

from project_code.display import *
# %matplotlib notebook
import random

# Retrieve the student data from a file
students = retrieve_students('./data.txt')
# Generate a normalized list of student data
student_list = normalize_student_data(students)

# %% [markdown]
# # Training Plots

# %% [markdown]
# ## Scenario B: Height and Weight

# %%
student_train = random.sample(student_list, 4000)
male_students_train, female_students_train = separate_normalized_students(student_train,gender_idx=2)
weights = [random.random() for i in range(3)]

# %%
title = "Scenario B: No Split, Height x Weight, Hard Activation, Alpha=0.1"
iterations=100
# Create the perceptron based on iterations and learning rate
p = Perceptron(ite=iterations, alpha=0.2)
# Train the Perceptron and obtain the resulting weights
hard_results = p.train(student_train, weights=weights, activation="hard")
# Plot the static data
plot_normalized_data(title, male_students_train, female_students_train, hard_results, dimensions=2)
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %%
title = "Scenario B: No Split, Height x Weight, Soft Activation, Alpha=0.1"
iterations=100
p = Perceptron(ite=iterations, alpha=0.1)
soft_results = p.train(student_train, weights=weights, activation="soft")
plot_normalized_data(title, male_students_train, female_students_train, soft_results, dimensions=2)
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %% [markdown]
# # Testing Plots

# %% [markdown]
# ## Scenario B: Height x Weight

# %% [markdown]
# ### 75/25 Train/Test Split

# %%
student_train = student_list[0:3000]
student_test = student_list[3000:len(student_list)]
male_students_test, female_students_test = separate_normalized_students(student_test,gender_idx=2)
weights = [random.random() for i in range(3)]

# %%
title = "Scenario A: 75/25 Height x Weight, Hard Activation, Alpha=0.1"
iterations=100
p = Perceptron(ite=iterations, alpha=0.1)
hard_results = p.train(student_train, weights=weights, activation="hard")
plot_normalized_data(title, male_students_test, female_students_test, hard_results, dimensions=2)
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %%
title = "Scenario A: 75/25 Height x Weight, Soft Activation, Alpha=0.1"
iterations=100
p = Perceptron(ite=iterations, alpha=0.1)
soft_results = p.train(student_train, weights=weights, activation="soft")
plot_normalized_data(title, male_students_test, female_students_test, soft_results, dimensions=2)
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %% [markdown]
# ### 50/50 Test/Train Split

# %%
student_train = student_list[0:2000]
student_test = student_list[2000:len(student_list)]
male_students_test, female_students_test = separate_normalized_students(student_test,gender_idx=2)
weights = [random.random() for i in range(3)]

# %%
title = "Scenario A: 50/50 Height x Weight, Hard Activation, Alpha=0.1"
iterations=100
p = Perceptron(ite=iterations, alpha=0.1)
hard_results = p.train(student_train, weights=weights, activation="hard")
plot_normalized_data(title, male_students_test, female_students_test, hard_results, dimensions=2)
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %%
title = "Scenario A: 50/50 Height x Weight, Soft Activation, Alpha=0.1"
iterations=100
p = Perceptron(ite=iterations, alpha=0.1)
soft_results = p.train(student_train, weights=weights, activation="soft")
plot_normalized_data(title, male_students_test, female_students_test, soft_results, dimensions=2)
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %% [markdown]
# ### 25/75 Train/Test Split

# %%
student_train = student_list[0:1000]
student_test = student_list[1000:len(student_list)]
male_students_test, female_students_test = separate_normalized_students(student_test,gender_idx=2)
weights = [random.random() for i in range(3)]

# %%
title = "Scenario A: 25/75 Height Only, Hard Activation, Alpha=0.1"
iterations=100
p = Perceptron(ite=iterations, alpha=0.1)
hard_results = p.train(student_train, weights=weights, activation="hard")
plot_normalized_data(title, male_students_test, female_students_test, hard_results, dimensions=2)
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %%
title = "Scenario A: 25/75 Height Only, Soft Activation, Alpha=0.1"
iterations=100
p = Perceptron(ite=iterations, alpha=0.1)
soft_results = p.train(student_train, weights=weights, activation="soft")
plot_normalized_data(title, male_students_test, female_students_test, soft_results, dimensions=2)
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">
